# %%
# 调用服务接口添加 question 的示例

import requests
import json

# 服务地址（根据实际情况修改）
BASE_URL = "http://127.0.0.1:80"  # 本地调试地址
# BASE_URL = "https://api.weixin.qq.com"
# BASE_URL = "https://your-domain.com"  # 生产环境地址

# 添加问题的接口地址
API_URL = f"{BASE_URL}/api/questions"

# %%
response = requests.get(
    f"{BASE_URL}/api/companies",
    headers={"Content-Type": "application/json"}
)

print(f"状态码: {response.status_code}")
# print(f"响应内容: {response.json()}")
# Out:
# 状态码: 200

# %%
for item in response.json()["data"]:
    print(item["name"])

# %%
response = requests.get(
    BASE_URL+"/api/question_detail"+"?question_id=528",
    headers={"Content-Type": "application/json"}
)

print(f"状态码: {response.status_code}")
print(f"响应内容: {response.json()}")
# Out:
# 状态码: 200
# 响应内容: {'code': 200, 'message': 'success', 'data': {'id': 528, 'company_name': 'belvedere', 'title': '三重匹配机会', 'level': 2, 'tags': '条件概率,组合数学,概率', 'firms': 'Belvedere Trading', 'content': '在赌场中，您有一个公平的 $6$ 面骰子、一个典型的轮盘赌轮（有 $38$ 插槽，包括两个零和数字 $1-36$），以及一副标准纸牌。  将 A 视为 1，当旋转轮盘、掷骰子、从牌堆中抽出一张牌时，所有显示相同数字的概率是多少？', 'solution': '骰子提供的可能性最少（只有 $1-6$），因此首先滚动骰子，让它显示随机的一面。  从牌堆中抽出具有该特定值的牌的概率为 $\\dfrac{1}{13}$。  轮盘赌停在该数字上的机会是 $\\dfrac{1}{38}$。  因此，假设独立，组合概率为 $\\dfrac{1}{13 \\cdot 38} = \\dfrac{1}{494}$。', 'answer': '__公式_0__', 'hint': '有多少价值观是所有人共同的？ __公式_0__'}}

# %%
# 示例2: 添加一个更复杂的面试题（基于 JSON 数据格式）
question_data = {
    "company_name": "jane_street",
    "name": "反转链表",
    "level": 2,  # 中等难度
}

response = requests.get(
    API_URL+"?company_id=1&tag=%E9%A9%AC%E5%B0%94%E5%8F%AF%E5%A4%AB%E9%93%BE&page=1&page_size=10",
    headers={"Content-Type": "application/json"}
)

print(f"状态码: {response.status_code}")
print(f"响应内容: {response.json()}")
# Out:
# 状态码: 200
# 响应内容: {'code': 200, 'message': 'success', 'data': {'list': [{'id': 524, 'title': '六连胜任务', 'difficulty': 2, 'tags': '马尔可夫链,期望值,概率'}], 'total': 1, 'page': 1, 'page_size': 10}}

# %%
# wx.cloud.callContainer.quantrex-backend/api/questions?company_id=1&tag=%E9%A9%AC%E5%B0%94%E5%8F%AF%E5%A4%AB%E9%93%BE&page=1&page_size=10
# Out:
# '马尔可夫链'

# %%
companies = [
    {
        "name": "belvedere",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/BeT.png?sign=e096a5eb5d0865ee1e123a36fb9b0ab3&t=1767013525"
    },
    {
        "name": "citadel",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/Citadel.png?sign=2a7fa5c6b0e8f835c36581d85e357dee&t=1767014897"
    },
    {
        "name": "goldman_sachs",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/GS.png?sign=209022640a9781615813d2ba304d76d5&t=1767014931"
    },
    {
        "name": "hrt",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/HRT.png?sign=d423a294b4783edb75500af66771aa26&t=1767014971"
    },
    {
        "name": "imc",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/IMC.jpeg?sign=9d446200d4f3ab39a92ab8fd47e6bcce&t=1767014990"
    },
    {
        "name": "squarepoint",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/SP.png?sign=d4ff3d675d119cb1cc477c9a9cab2f55&t=1767015026"
    },
    {
        "name": "worldquant",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/WorldQuant.jpeg?sign=c8f60f666a7667338580df8ba3c75a44&t=1767015182"
    },
    {
        "name": "transmarket",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/TMG.png?sign=2a19cabfdbcfa48bc7bc43e7ccc0cdcb&t=1767015122"
    },
    {
        "name": "akuna",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/akuna.png?sign=d6bb379480914994728cec6f38b23925&t=1767015234"
    },
    {
        "name": "drw",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/drw.png?sign=cdc231f8c0785a92609f1e9f1d144386&t=1767015265"
    },
    {
        "name": "five_rings",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/fiverings.png?sign=bf5af3c172691d89932b726691d07624&t=1767015305"
    },
    {
        "name": "jane_street",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/jane_street.png?sign=e9ebd8545cd655417d4f3479d382e557&t=1767015711"
    },
    {
        "name": "oldmission",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/oldmission.png?sign=70a5987683ffc0dd2e7433c38c567b22&t=1767015798"
    },
    {
        "name": "optiver",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/optiver.png?sign=fed7e9a8b27288f0566e6c511af9f447&t=1767015846"
    },
    {
        "name": "sig",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/sis.png?sign=b63b090f6ad81cfc23ab07b50dcee141&t=1767015875"
    },
    {
        "name": "two_sigma",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/two_sigmal.png?sign=82c49d0be19e01f97cdbb6b289155c02&t=1767015920"
    },
    {
        "name": "九坤",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/%E4%B9%9D%E5%9D%A4.png?sign=df33005153bd324b30d468fb32af1877&t=1767015959"
    },
    {
        "name": "世纪前沿",
        "image_url": "https://7072-prod-8g9e1d5rd505fc38-1383327678.tcb.qcloud.la/%E4%B8%96%E7%BA%AA%E5%89%8D%E6%B2%BF.png?sign=67434efd903c2f970a565203821fa29a&t=1767015990"
    },
]
